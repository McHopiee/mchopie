# %%
---
layout: post
title: Practice MCQ Important Questions 
description: After taking the MCQ, these are the questions that brought some concerns.
categories: [Personal]
permalink: /personal/practiceMCQ
authors: [Hope]
comments: true
---
