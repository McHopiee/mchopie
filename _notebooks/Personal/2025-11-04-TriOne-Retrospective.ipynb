# %%
---
layout: tailwindPost
infograph: retrospective
microblog: true 
title: Retrospective Review - CSP Trimester One 
description: Final review of CSP Trimester One, first and second sprints.
categories: [Personal]
permalink: /personal/trione-retrospective
authors: [Hope]
comments: true
---

# %% [markdown]
# {%- include tailwind/trione-retrospective.html -%}
