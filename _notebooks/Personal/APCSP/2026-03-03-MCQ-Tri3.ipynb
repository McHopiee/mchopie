# %% [markdown]
# ---
# layout: tailwindPost
# infoGraph: cspfinal
# title: AP CSP - Practice MCQ Check 3/3/27
# permalink: /personal/mcq2020
# author: Hope Fune
# categories: [Personal]
# ---

# %% [markdown]
# {%- include tailwind/practice_mcq_overview_infograph.html -%}
