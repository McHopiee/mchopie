# %% [markdown]
# ---
# layout: tailwindPost
# infoGraph: cspfinal
# title: AP CSP - Final Tri 2
# permalink: /personal/finalcsp
# author: Hope Fune
# categories: [Personal]
# ---

# %% [markdown]
# {%- include tailwind/cspfinal_infograph.html -%}
