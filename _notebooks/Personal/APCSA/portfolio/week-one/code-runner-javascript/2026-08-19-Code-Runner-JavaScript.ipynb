# %% [markdown]
# ---
# layout: post
# title: Code Runner - JavaScript
# description: CSA Week One - Code Runner (JavaScript)
# permalink: /personal/csa/coderunner-javascript
# author: Hope Fune
# categories: [CSA Portfolio]
# ---

# %% [markdown]
# <style>
# 	.pokedex { --poke-red: #e3350d; --poke-red-dark: #b02e0c; --poke-yellow: #ffcb05; --poke-blue: #3b4cca; --poke-dark: #232323; --poke-cream: #f6f6f6; background: linear-gradient(to bottom, var(--poke-red) 0%, var(--poke-red) 4.5rem, var(--poke-cream) 4.5rem, var(--poke-cream) 100%); border: 4px solid var(--poke-dark); border-radius: 1.25rem; color: var(--poke-dark); font-family: system-ui, sans-serif; margin: 0 -1rem 1.5rem; overflow: hidden; padding: 1.5rem 1.5rem 2rem; }
# 	.pokedex-header { align-items: center; display: flex; gap: 1rem; margin-bottom: 1.5rem; }
# 	.pokeball { animation: poke-spin 6s linear infinite; background: linear-gradient(to bottom, var(--poke-red) 0%, var(--poke-red) 46%, var(--poke-dark) 46%, var(--poke-dark) 54%, var(--poke-cream) 54%, var(--poke-cream) 100%); border: 3px solid var(--poke-dark); border-radius: 50%; flex-shrink: 0; height: 3rem; position: relative; width: 3rem; }
# 	.pokeball::after { background: var(--poke-cream); border: 3px solid var(--poke-dark); border-radius: 50%; content: ''; height: .9rem; left: 50%; position: absolute; top: 50%; transform: translate(-50%, -50%); width: .9rem; }
# 	@keyframes poke-spin { from { transform: rotate(0deg); } to { transform: rotate(360deg); } }
# 	.pokedex-title { color: var(--poke-cream); font-size: clamp(1.8rem, 5vw, 2.6rem); font-weight: 800; letter-spacing: -.02em; margin: 0; text-shadow: -1px -1px 0 var(--poke-dark), 1px -1px 0 var(--poke-dark), -1px 1px 0 var(--poke-dark), 1px 1px 0 var(--poke-dark); }
# 	.pokedex-subtitle { color: #232323 !important; font: 600 .85rem/1.5 system-ui, sans-serif; margin: .15rem 0 0; }
# 	.pokedex-back { background: var(--poke-dark); border-radius: 999px; color: var(--poke-cream) !important; display: inline-block; font: 700 .75rem monospace; letter-spacing: .05em; margin-bottom: 1rem; padding: .35rem .9rem; text-decoration: none; text-transform: uppercase; transition: background .2s ease, transform .2s ease; }
# 	.pokedex-back:hover { background: var(--poke-red); transform: translateX(-.2rem); }
# 	.pokedex-label { background: var(--poke-yellow); border: 2px solid var(--poke-dark); border-radius: .4rem; color: var(--poke-dark); display: inline-block; font: 700 .75rem monospace; letter-spacing: .06em; margin: 0 0 1rem; padding: .25rem .6rem; text-transform: uppercase; }
# 	.pokedex h3 { color: #232323 !important; }
# 	#javascript-main { background: var(--poke-dark); border: 4px solid var(--poke-blue); border-radius: .75rem; padding: 1rem; }
# 	#javascript-main-editor, #javascript-main-output { background: #d7f4c0; border: 2px solid var(--poke-dark); border-radius: .4rem; color: #14331a; font-family: 'Courier New', monospace; }
# 	#javascript-main-output { padding: .75rem; }
# 	#javascript-main-run { background: var(--poke-red); border: none; border-radius: 999px; color: #fff; cursor: pointer; font-weight: 700; letter-spacing: .04em; padding: .5rem 1.25rem; text-transform: uppercase; transition: background .15s ease, transform .15s ease; }
# 	#javascript-main-run:hover { background: var(--poke-red-dark); transform: scale(1.05); }
# 	@media (prefers-reduced-motion: reduce) { .pokeball { animation: none; } }
# </style>
#
# <div class="pokedex" markdown="1">
# <div class="pokedex-header">
# <span class="pokeball" aria-hidden="true"></span>
# <div>
# <p class="pokedex-title">Code Runner - Javascript</p>
# <p class="pokedex-subtitle">Professor Oak's JavaScript Lab &mdash; catch some output!</p>
# </div>
# </div>

# %% [markdown]
# <a class="pokedex-back" href="{{ site.baseurl }}/personal/csa/week-one/">&larr; Back</a>

# %% [markdown]
# <span class="pokedex-label">Pokedex Terminal</span>
#
# ### First Test

# %% [markdown]
# {% capture javascript_example %}
# console.log("Hello");
# {% endcapture %}
# {% include runners/code-js.html runner_id="javascript-main" code=javascript_example %}

# %% [markdown]
# </div>
