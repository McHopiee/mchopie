# %% [markdown]
# ---
# layout: post
# title: Code Runner
# description: CSA Week One - Code Runner
# permalink: /personal/csa/coderunner
# author: Hope Fune
# categories: [CSA Portfolio]
# ---

# %% [markdown]
# <style>
#   .pokedex {
#     --poke-red: #B74555;
#     --poke-red-dark: #96323f;
#     --poke-yellow: #ffcb05;
#     --poke-blue: #49896F;
#     --poke-dark: #232323;
#     --poke-cream: #f6f6f6;
#     --bulb-green: #89C893;
#     --bulb-green-dark: #49896F;
#     --bulb-sea: #92D1B3;
#     --bulb-pink: #BD92AF;
#     background: linear-gradient(to bottom, var(--bulb-green) 0%, var(--bulb-green) 4.5rem, var(--poke-cream) 4.5rem, var(--poke-cream) 100%);
#     border: 4px solid var(--bulb-green-dark);
#     border-radius: 1.25rem;
#     color: var(--poke-dark);
#     font-family: system-ui, sans-serif;
#     margin: 0 -1rem 1.5rem;
#     overflow: hidden;
#     padding: 1.5rem 1.5rem 2rem;
#     position: relative;
#   }
#   .pokedex::before, .pokedex::after {
#     content: '\1F343';
#     font-size: 1.4rem;
#     opacity: .5;
#     position: absolute;
#   }
#   .pokedex::before { left: .75rem; top: .25rem; transform: rotate(-15deg); }
#   .pokedex::after { right: .75rem; top: .25rem; transform: rotate(15deg) scaleX(-1); }
#
#   .pokedex-header { align-items: center; display: flex; gap: 1rem; margin-bottom: 1.5rem; position: relative; z-index: 1; }
#   .pokeball {
#     animation: poke-spin 6s linear infinite;
#     background: linear-gradient(to bottom, var(--bulb-green) 0%, var(--bulb-green) 46%, var(--bulb-green-dark) 46%, var(--bulb-green-dark) 54%, var(--poke-cream) 54%, var(--poke-cream) 100%);
#     border: 3px solid var(--bulb-green-dark);
#     border-radius: 50%;
#     flex-shrink: 0;
#     height: 3rem;
#     position: relative;
#     width: 3rem;
#   }
#   .pokeball::after {
#     background: var(--poke-red);
#     border: 2px solid var(--bulb-green-dark);
#     border-radius: 50%;
#     content: '';
#     height: .9rem;
#     left: 50%;
#     position: absolute;
#     top: 50%;
#     transform: translate(-50%, -50%);
#     width: .9rem;
#   }
#   @keyframes poke-spin { from { transform: rotate(0deg); } to { transform: rotate(360deg); } }
#   .pokedex-title {
#     color: var(--poke-cream);
#     font-size: clamp(1.8rem, 5vw, 2.6rem);
#     font-weight: 800;
#     letter-spacing: -.02em;
#     margin: 0;
#     text-shadow: -1px -1px 0 var(--bulb-green-dark), 1px -1px 0 var(--bulb-green-dark), -1px 1px 0 var(--bulb-green-dark), 1px 1px 0 var(--bulb-green-dark);
#   }
#   .pokedex-subtitle { color: #232323 !important; font: 600 .85rem/1.5 system-ui, sans-serif; margin: .15rem 0 0; }
#   .pokedex-subtitle::before { content: '\1F33F '; }
#   .pokedex-back {
#     background: var(--bulb-green-dark);
#     border-radius: 999px;
#     color: var(--poke-cream) !important;
#     display: inline-block;
#     font: 700 .75rem monospace;
#     letter-spacing: .05em;
#     margin-bottom: 1rem;
#     padding: .35rem .9rem;
#     text-decoration: none;
#     text-transform: uppercase;
#     transition: background .2s ease, transform .2s ease;
#   }
#   .pokedex-back:hover { background: var(--poke-red); transform: translateX(-.2rem); }
#   .pokedex-label {
#     background: var(--bulb-sea);
#     border: 2px solid var(--bulb-green-dark);
#     border-radius: .4rem;
#     color: var(--poke-dark);
#     display: inline-block;
#     font: 700 .75rem monospace;
#     letter-spacing: .06em;
#     margin: 0 0 1rem;
#     padding: .25rem .6rem;
#     text-transform: uppercase;
#   }
#   .pokedex-label::before { content: '\1F33F '; }
#   .pokedex h3 {
#     color: #14331a !important;
#     margin-top: 1rem;
#   }
#
#   #python-main, #python-bulb-1, #python-bulb-2, #python-bulb-3 {
#     background: var(--bulb-green-dark);
#     border: 4px solid var(--bulb-sea);
#     border-radius: .75rem;
#     margin-bottom: 1rem;
#     padding: 1rem;
#   }
#   #python-main-editor, #python-main-output,
#   #python-bulb-1-editor, #python-bulb-1-output,
#   #python-bulb-2-editor, #python-bulb-2-output,
#   #python-bulb-3-editor, #python-bulb-3-output {
#     background: #d7f4c0;
#     border: 2px solid var(--bulb-green-dark);
#     border-radius: .4rem;
#     color: #14331a;
#     font-family: 'Courier New', monospace;
#   }
#   #python-main-output, #python-bulb-1-output, #python-bulb-2-output, #python-bulb-3-output { padding: .75rem; }
#   #python-main-run, #python-bulb-1-run, #python-bulb-2-run, #python-bulb-3-run {
#     background: var(--poke-red);
#     border: none;
#     border-radius: 999px;
#     color: #fff;
#     cursor: pointer;
#     font-weight: 700;
#     letter-spacing: .04em;
#     padding: .5rem 1.25rem;
#     text-transform: uppercase;
#     transition: background .15s ease, transform .15s ease;
#   }
#   #python-main-run:hover, #python-bulb-1-run:hover, #python-bulb-2-run:hover, #python-bulb-3-run:hover {
#     background: var(--poke-red-dark);
#     transform: scale(1.05);
#   }
#   .pokedex-vine {
#     background: repeating-linear-gradient(115deg, var(--bulb-green-dark) 0 6px, transparent 6px 14px);
#     border-radius: 999px;
#     height: 4px;
#     margin: 0 0 1.25rem;
#     opacity: .6;
#     width: 100%;
#   }
#   @media (prefers-reduced-motion: reduce) { .pokeball { animation: none; } }
# </style>
#
# <div class="pokedex" markdown="1">
# <div class="pokedex-header">
# <span class="pokeball" aria-hidden="true"></span>
# <div>
# <p class="pokedex-title">Code Runner - Raw MD</p>
# <p class="pokedex-subtitle">Professor Oak's Python Lab &mdash; catch some output!</p>
# </div>
# </div>
#
# <a class="pokedex-back" href="{{ site.baseurl }}/personal/csa/week-one/">&larr; Back</a>
#
# <span class="pokedex-label">Pokedex Terminal</span>
# <div class="pokedex-vine" aria-hidden="true"></div>
#
# ### First Test
#
# {% capture python_example %}
# print("Wassaauppp")
# {% endcapture %}
# {% include runners/code.html runner_id="python-main" language="python" code=python_example %}
#
# ### Runner 1 - Bulbasaur Says Hello
#
# {% capture python_bulbasaur_hello %}
# print("Hello, Bulbasaur!")
# {% endcapture %}
# {% include runners/code.html runner_id="python-bulb-1" language="python" code=python_bulbasaur_hello success_gif="/images/gifs/bulbasaurone.gif" success_gif_alt="Bulbasaur celebrating" %}
#
# ### Runner 2 - Trainer Greeting
#
# Use the prompts to enter your answers, then see Bulbasaur's response.
#
# {% capture python_bulbasaur_stats %}
# name = input("Trainer, what is your name? ")
# favorite_type = input("What is your favorite Pokemon type? ")
#
# print()
# print("Welcome,", name + "!")
# print("Ah,", favorite_type, "type! A great choice.")
# print("Bulbasaur approves!")
# {% endcapture %}
# {% include runners/code.html runner_id="python-bulb-2" language="python" code=python_bulbasaur_stats success_gif="/images/gifs/bulbasaurtwo.gif" success_gif_alt="Bulbasaur celebrating" %}
#
# ### Runner 3 - Bulbasaur's Training
#
# Now try numbers + conditionals. Enter a name and level to see different outcomes.
#
# {% capture python_bulbasaur_training %}
# name = input("What is your Bulbasaur's name? ")
# level = int(input("What level is " + name + "? "))
#
# print()
# if level >= 16:
#   print(name, "is ready to evolve!")
# elif level >= 10:
#   print(name, "is getting stronger!")
# else:
#   print(name, "needs more training!")
# {% endcapture %}
# {% include runners/code.html runner_id="python-bulb-3" language="python" code=python_bulbasaur_training success_gif="/images/gifs/bulbasaurthree.gif" success_gif_alt="Bulbasaur celebrating" %}
#
# </div>
