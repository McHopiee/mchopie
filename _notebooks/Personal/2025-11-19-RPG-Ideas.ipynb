# %%
---
layout: tailwindPost
infoGraph: rpg_storyboard
title: Storyboard rpg idea 
description: Storyboard and ideas for RPG ' creator and helper '
categories: [Personal]
permalink: /personal/attendance
authors: [Hope]
comments: true
---

# %% [markdown]
# {%- include tailwind/rpg-storyboard.html -%}
